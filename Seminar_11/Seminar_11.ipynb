# %%
# f(x) = sin(x)^2 - cos(x)^2

# 1. Определить корни
# 2. Найти интервалы, на которых функция возрастает
# 3. Найти интервалы, на которых функция убывает
# 4. Построить график
# 5. Вычислить вершину
# 6. Определить промежутки, на котором f > 0
# 7. Определить промежутки, на котором f < 0

from sympy import Symbol, sin, cos, pprint, solve, evalf, pprint, solveset, diff, S 
from sympy.plotting import plot

x = Symbol('x')
f = sin(x)**2 - cos(x)**2

# %%
# 1. Определить корни
pprint(solveset(f, x, domain = S.Reals), use_unicode=True)
# Out:
# ⎧      π │      ⎫   ⎧      3⋅π │      ⎫
# ⎨n⋅π + ─ │ n ∊ ℤ⎬ ∪ ⎨n⋅π + ─── │ n ∊ ℤ⎬
# ⎩      4 │      ⎭   ⎩       4  │      ⎭

# %%
# 2. Найти интервалы, на которых функция возрастает
pprint(solveset(diff_f > 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛   π⎞
# ⎜0, ─⎟
# ⎝   2⎠

# %%
# 3. Найти интервалы, на которых функция убывает
pprint(solveset(diff_f < 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛π   ⎞
# ⎜─, π⎟
# ⎝2   ⎠

# %%
# 4. Построить график
p1 = plot(f, show=False)
p1.show()

# %%
# 5. Вычислить вершину
diff_f = diff(f,x)
print(diff_f)
solve(diff_f,x)
# Out:
# 4*sin(x)*cos(x)
# [0, pi/2, pi, 3*pi/2]

# %%
# 6. Определить промежутки, на котором f > 0
pprint(solveset(f > 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛π  3⋅π⎞
# ⎜─, ───⎟
# ⎝4   4 ⎠

# %%
# 7. Определить промежутки, на котором f < 0
pprint(solveset(f < 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎡   π⎞   ⎛3⋅π   ⎞
# ⎢0, ─⎟ ∪ ⎜───, π⎟
# ⎣   4⎠   ⎝ 4    ⎠
